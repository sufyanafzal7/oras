# %% [markdown]
# **build_master_dataset.py**

# %% [markdown]
# C:\Windows\System32>cd /d D:\Projects\oras\ml
#
# D:\Projects\oras\ml>.\venv\Scripts\activate
#
# (venv) D:\Projects\oras\ml>python scripts\build_master_dataset.py
# Found 80 videos with phase annotations.
#   + video01: 1733 rows
#   + video02: 2839 rows
#   + video03: 5828 rows
#   + video04: 1522 rows
#   + video05: 2344 rows
#   + video06: 2153 rows
#   + video07: 4557 rows
#   + video08: 1519 rows
#   + video09: 2702 rows
#   + video10: 1749 rows
#   + video11: 3220 rows
#   + video12: 1090 rows
#   + video13: 981 rows
#   + video14: 1708 rows
#   + video15: 2058 rows
#   + video16: 2957 rows
#   + video17: 1304 rows
#   + video18: 1942 rows
#   + video19: 2424 rows
#   + video20: 1449 rows
#   + video21: 1258 rows
#   + video22: 1532 rows
#   + video23: 1635 rows
#   + video24: 1975 rows
#   + video25: 2129 rows
#   + video26: 1773 rows
#   + video27: 2084 rows
#   + video28: 1199 rows
#   + video29: 2350 rows
#   + video30: 2925 rows
#   + video31: 3945 rows
#   + video32: 2116 rows
#   + video33: 1307 rows
#   + video34: 1323 rows
#   + video35: 2106 rows
#   + video36: 2387 rows
#   + video37: 1232 rows
#   + video38: 3080 rows
#   + video39: 1647 rows
#   + video40: 2222 rows
#   + video41: 3103 rows
#   + video42: 3712 rows
#   + video43: 2362 rows
#   + video44: 3127 rows
#   + video45: 3387 rows
#   + video46: 1653 rows
#   + video47: 2259 rows
#   + video48: 1834 rows
#   + video49: 1671 rows
#   + video50: 1094 rows
#   + video51: 2944 rows
#   + video52: 1966 rows
#   + video53: 3283 rows
#   + video54: 3100 rows
#   + video55: 1037 rows
#   + video56: 1834 rows
#   + video57: 2632 rows
#   + video58: 5993 rows
#   + video59: 1046 rows
#   + video60: 2532 rows
#   + video61: 4409 rows
#   + video62: 2032 rows
#   + video63: 3433 rows
#   + video64: 2398 rows
#   + video65: 1873 rows
#   + video66: 1824 rows
#   + video67: 2353 rows
#   + video68: 1972 rows
#   + video69: 4575 rows
#   + video70: 1194 rows
#   + video71: 2515 rows
#   + video72: 3106 rows
#   + video73: 1356 rows
#   + video74: 1634 rows
#   + video75: 1923 rows
#   + video76: 2649 rows
#   + video77: 2502 rows
#   + video78: 739 rows
#   + video79: 3414 rows
#   + video80: 1724 rows
#
# Saved -> D:\Projects\oras\ml\datasets\cholec80_master.csv
# Total rows: 184498  |  Videos: 80
#
# Phase distribution:
# phase
# CalotTriangleDissection    74826
# GallbladderDissection      58433
# CleaningCoagulation        14332
# ClippingCutting            14080
# Preparation                 8574
# GallbladderPackaging        7618
# GallbladderRetraction       6635
# Name: count, dtype: int64
#
# Tool presence rate (% of frames):
# grasper        55.6
# bipolar         4.8
# hook           55.9
# scissors        1.8
# clipper         3.2
# irrigator       5.3
# specimenbag     6.2
# dtype: float64
#
# (venv) D:\Projects\oras\ml>

# %% [markdown]
# **extract_frames.py**

# %% [markdown]
# (venv) D:\Projects\oras\ml>python scripts\extract_frames.py
# Found 80 videos in D:\Download\Dataset\videos
#   > video01: extracting...
#     saved 1734 frames -> D:\Projects\oras\ml\datasets\cholec80_frames\video01
#   > video02: extracting...
#     saved 2840 frames -> D:\Projects\oras\ml\datasets\cholec80_frames\video02
#   > video03: extracting...
#     saved 5829 frames -> D:\Projects\oras\ml\datasets\cholec80_frames\video03
#   > video04: extracting...
#     saved 1523 frames -> D:\Projects\oras\ml\datasets\cholec80_frames\video04
#   > video05: extracting...
#     saved 2345 frames -> D:\Projects\oras\ml\datasets\cholec80_frames\video05
#   > video06: extracting...
#     saved 2154 frames -> D:\Projects\oras\ml\datasets\cholec80_frames\video06
#   > video07: extracting...
#     saved 4558 frames -> D:\Projects\oras\ml\datasets\cholec80_frames\video07
#   > video08: extracting...
#     saved 1520 frames -> D:\Projects\oras\ml\datasets\cholec80_frames\video08
#   > video09: extracting...
#     saved 2703 frames -> D:\Projects\oras\ml\datasets\cholec80_frames\video09
#   > video10: extracting...
#     saved 1750 frames -> D:\Projects\oras\ml\datasets\cholec80_frames\video10
#   > video11: extracting...
#     saved 3221 frames -> D:\Projects\oras\ml\datasets\cholec80_frames\video11
#   > video12: extracting...
#     saved 1091 frames -> D:\Projects\oras\ml\datasets\cholec80_frames\video12
#   > video13: extracting...
#     saved 982 frames -> D:\Projects\oras\ml\datasets\cholec80_frames\video13
#   > video14: extracting...
#     saved 1709 frames -> D:\Projects\oras\ml\datasets\cholec80_frames\video14
#   > video15: extracting...
#     saved 2059 frames -> D:\Projects\oras\ml\datasets\cholec80_frames\video15
#   > video16: extracting...
#     saved 2958 frames -> D:\Projects\oras\ml\datasets\cholec80_frames\video16
#   > video17: extracting...
#     saved 1305 frames -> D:\Projects\oras\ml\datasets\cholec80_frames\video17
#   > video18: extracting...
#     saved 1943 frames -> D:\Projects\oras\ml\datasets\cholec80_frames\video18
#   > video19: extracting...
#     saved 2425 frames -> D:\Projects\oras\ml\datasets\cholec80_frames\video19
#   > video20: extracting...
#     saved 1450 frames -> D:\Projects\oras\ml\datasets\cholec80_frames\video20
#   > video21: extracting...
#     saved 1259 frames -> D:\Projects\oras\ml\datasets\cholec80_frames\video21
#   > video22: extracting...
#     saved 1533 frames -> D:\Projects\oras\ml\datasets\cholec80_frames\video22
#   > video23: extracting...
#     saved 1636 frames -> D:\Projects\oras\ml\datasets\cholec80_frames\video23
#   > video24: extracting...
#     saved 1976 frames -> D:\Projects\oras\ml\datasets\cholec80_frames\video24
#   > video25: extracting...
#     saved 2130 frames -> D:\Projects\oras\ml\datasets\cholec80_frames\video25
#   > video26: extracting...
#     saved 1774 frames -> D:\Projects\oras\ml\datasets\cholec80_frames\video26
#   > video27: extracting...
#     saved 2085 frames -> D:\Projects\oras\ml\datasets\cholec80_frames\video27
#   > video28: extracting...
#     saved 1200 frames -> D:\Projects\oras\ml\datasets\cholec80_frames\video28
#   > video29: extracting...
#     saved 2351 frames -> D:\Projects\oras\ml\datasets\cholec80_frames\video29
#   > video30: extracting...
#     saved 2926 frames -> D:\Projects\oras\ml\datasets\cholec80_frames\video30
#   > video31: extracting...
#     saved 3946 frames -> D:\Projects\oras\ml\datasets\cholec80_frames\video31
#   > video32: extracting...
#     saved 2117 frames -> D:\Projects\oras\ml\datasets\cholec80_frames\video32
#   > video33: extracting...
#     saved 1308 frames -> D:\Projects\oras\ml\datasets\cholec80_frames\video33
#   > video34: extracting...
#     saved 1324 frames -> D:\Projects\oras\ml\datasets\cholec80_frames\video34
#   > video35: extracting...
#     saved 2107 frames -> D:\Projects\oras\ml\datasets\cholec80_frames\video35
#   > video36: extracting...
#     saved 2388 frames -> D:\Projects\oras\ml\datasets\cholec80_frames\video36
#   > video37: extracting...
#     saved 1233 frames -> D:\Projects\oras\ml\datasets\cholec80_frames\video37
#   > video38: extracting...
#     saved 3081 frames -> D:\Projects\oras\ml\datasets\cholec80_frames\video38
#   > video39: extracting...
#     saved 1648 frames -> D:\Projects\oras\ml\datasets\cholec80_frames\video39
#   > video40: extracting...
#     saved 2223 frames -> D:\Projects\oras\ml\datasets\cholec80_frames\video40
#   > video41: extracting...
#     saved 3104 frames -> D:\Projects\oras\ml\datasets\cholec80_frames\video41
#   > video42: extracting...
#     saved 3713 frames -> D:\Projects\oras\ml\datasets\cholec80_frames\video42
#   > video43: extracting...
#     saved 2363 frames -> D:\Projects\oras\ml\datasets\cholec80_frames\video43
#   > video44: extracting...
#     saved 3128 frames -> D:\Projects\oras\ml\datasets\cholec80_frames\video44
#   > video45: extracting...
#     saved 3388 frames -> D:\Projects\oras\ml\datasets\cholec80_frames\video45
#   > video46: extracting...
#     saved 1654 frames -> D:\Projects\oras\ml\datasets\cholec80_frames\video46
#   > video47: extracting...
#     saved 2260 frames -> D:\Projects\oras\ml\datasets\cholec80_frames\video47
#   > video48: extracting...
#     saved 1835 frames -> D:\Projects\oras\ml\datasets\cholec80_frames\video48
#   > video49: extracting...
#     saved 1672 frames -> D:\Projects\oras\ml\datasets\cholec80_frames\video49
#   > video50: extracting...
#     saved 1095 frames -> D:\Projects\oras\ml\datasets\cholec80_frames\video50
#   > video51: extracting...
#     saved 2945 frames -> D:\Projects\oras\ml\datasets\cholec80_frames\video51
#   > video52: extracting...
#     saved 1967 frames -> D:\Projects\oras\ml\datasets\cholec80_frames\video52
#   > video53: extracting...
#     saved 3284 frames -> D:\Projects\oras\ml\datasets\cholec80_frames\video53
#   > video54: extracting...
#     saved 3101 frames -> D:\Projects\oras\ml\datasets\cholec80_frames\video54
#   > video55: extracting...
#     saved 1038 frames -> D:\Projects\oras\ml\datasets\cholec80_frames\video55
#   > video56: extracting...
#     saved 1835 frames -> D:\Projects\oras\ml\datasets\cholec80_frames\video56
#   > video57: extracting...
#     saved 2633 frames -> D:\Projects\oras\ml\datasets\cholec80_frames\video57
#   > video58: extracting...
#     saved 5994 frames -> D:\Projects\oras\ml\datasets\cholec80_frames\video58
#   > video59: extracting...
#     saved 1047 frames -> D:\Projects\oras\ml\datasets\cholec80_frames\video59
#   > video60: extracting...
#     saved 2533 frames -> D:\Projects\oras\ml\datasets\cholec80_frames\video60
#   > video61: extracting...
#     saved 4410 frames -> D:\Projects\oras\ml\datasets\cholec80_frames\video61
#   > video62: extracting...
#     saved 2033 frames -> D:\Projects\oras\ml\datasets\cholec80_frames\video62
#   > video63: extracting...
#     saved 3434 frames -> D:\Projects\oras\ml\datasets\cholec80_frames\video63
#   > video64: extracting...
#     saved 2399 frames -> D:\Projects\oras\ml\datasets\cholec80_frames\video64
#   > video65: extracting...
#     saved 1874 frames -> D:\Projects\oras\ml\datasets\cholec80_frames\video65
#   > video66: extracting...
#     saved 1825 frames -> D:\Projects\oras\ml\datasets\cholec80_frames\video66
#   > video67: extracting...
#     saved 2354 frames -> D:\Projects\oras\ml\datasets\cholec80_frames\video67
#   > video68: extracting...
#     saved 1973 frames -> D:\Projects\oras\ml\datasets\cholec80_frames\video68
#   > video69: extracting...
#     saved 4576 frames -> D:\Projects\oras\ml\datasets\cholec80_frames\video69
#   > video70: extracting...
#     saved 1195 frames -> D:\Projects\oras\ml\datasets\cholec80_frames\video70
#   > video71: extracting...
#     saved 2516 frames -> D:\Projects\oras\ml\datasets\cholec80_frames\video71
#   > video72: extracting...
#     saved 3107 frames -> D:\Projects\oras\ml\datasets\cholec80_frames\video72
#   > video73: extracting...
#     saved 1357 frames -> D:\Projects\oras\ml\datasets\cholec80_frames\video73
#   > video74: extracting...
#     saved 1635 frames -> D:\Projects\oras\ml\datasets\cholec80_frames\video74
#   > video75: extracting...
#     saved 1924 frames -> D:\Projects\oras\ml\datasets\cholec80_frames\video75
#   > video76: extracting...
#     saved 2650 frames -> D:\Projects\oras\ml\datasets\cholec80_frames\video76
#   > video77: extracting...
#     saved 2503 frames -> D:\Projects\oras\ml\datasets\cholec80_frames\video77
#   > video78: extracting...
#     saved 740 frames -> D:\Projects\oras\ml\datasets\cholec80_frames\video78
#   > video79: extracting...
#     saved 3415 frames -> D:\Projects\oras\ml\datasets\cholec80_frames\video79
#   > video80: extracting...
#     saved 1725 frames -> D:\Projects\oras\ml\datasets\cholec80_frames\video80
#
# (venv) D:\Projects\oras\ml>
